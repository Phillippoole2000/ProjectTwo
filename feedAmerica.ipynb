# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

import numpy as np

# Study data files
feedA_metadata = "data/feedAmerica.csv"

# Read the data
feedA_metadata = pd.read_csv(feedA_metadata)
feedA_metadata
# Out:
#        FIPS State               County, State 2018 Food Insecurity Rate  \
# 0      1001    AL     Autauga County, Alabama                     15.6%
# 1      1003    AL     Baldwin County, Alabama                     12.9%
# 2      1005    AL     Barbour County, Alabama                     21.9%
# 3      1007    AL        Bibb County, Alabama                     15.1%
# 4      1009    AL      Blount County, Alabama                     13.6%
# ...     ...   ...                         ...                       ...
# 3137  56037    WY  Sweetwater County, Wyoming                     11.7%
# 3138  56039    WY       Teton County, Wyoming                      9.5%
# 3139  56041    WY       Uinta County, Wyoming                     13.5%
# 3140  56043    WY    Washakie County, Wyoming                     12.6%
# 3141  56045    WY      Weston County, Wyoming                     14.0%
#
#      # of Food Insecure Persons in 2018 Low Threshold in state  \
# ...

# %%
il_feedA = feedA_metadata.loc[feedA_metadata["State"] == "IL"]
il_feedA
# Out:
#       FIPS State                County, State 2018 Food Insecurity Rate  \
# 595  17001    IL       Adams County, Illinois                     10.2%
# 596  17003    IL   Alexander County, Illinois                     19.5%
# 597  17005    IL        Bond County, Illinois                     10.3%
# 598  17007    IL       Boone County, Illinois                      8.7%
# 599  17009    IL       Brown County, Illinois                      8.6%
# ..     ...   ...                          ...                       ...
# 692  17195    IL   Whiteside County, Illinois                      9.4%
# 693  17197    IL        Will County, Illinois                      6.1%
# 694  17199    IL  Williamson County, Illinois                     12.5%
# 695  17201    IL   Winnebago County, Illinois                     12.0%
# 696  17203    IL    Woodford County, Illinois                      7.3%
#
#     # of Food Insecure Persons in 2018 Low Threshold in state  \
# ...

# %%
il_feedA.columns
# Out:
# Index(['FIPS', 'State', 'County, State', '2018 Food Insecurity Rate',
#        '# of Food Insecure Persons in 2018', 'Low Threshold in state',
#        'Low Threshold Type', 'High Threshold in state', 'High Threshold Type',
#        '% FI ≤ Low Threshold', '% FI Btwn Thresholds', '% FI > High Threshold',
#        '2018 Child food insecurity rate',
#        '# of Food Insecure Children in 2018',
#        '% food insecure children in HH w/ HH incomes below 185 FPL in 2018',
#        '% food insecure children in HH w/ HH incomes above 185 FPL in 2018',
#        '2018 Cost Per Meal', '2018 Weighted Annual Food Budget Shortfall'],
#       dtype='object')

# %%
il_2018 = il_feedA[["County, State", "2018 Food Insecurity Rate", "2018 Child food insecurity rate","2018 Cost Per Meal", "2018 Weighted Annual Food Budget Shortfall"]]
il_2018 = il_2018.rename(columns={"2018 Food Insecurity Rate": "2018_food_insecurity_rate","2018 Cost Per Meal": "2018_cost_meal","2018 Weighted Annual Food Budget Shortfall":"2018_food_budget" })
il_2018
# Out:
#                    County, State 2018_food_insecurity_rate  \
# 595       Adams County, Illinois                     10.2%
# 596   Alexander County, Illinois                     19.5%
# 597        Bond County, Illinois                     10.3%
# 598       Boone County, Illinois                      8.7%
# 599       Brown County, Illinois                      8.6%
# ..                           ...                       ...
# 692   Whiteside County, Illinois                      9.4%
# 693        Will County, Illinois                      6.1%
# 694  Williamson County, Illinois                     12.5%
# 695   Winnebago County, Illinois                     12.0%
# 696    Woodford County, Illinois                      7.3%
#
#     2018 Child food insecurity rate 2018_cost_meal 2018_food_budget
# 595                           14.2%          $2.85    $3,263,000.00
# 596                           32.4%          $2.83      $609,000.00
# ...

# %%
il_2018.to_csv("il_2018.csv")
