# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

import numpy as np

# Study data files
foodAccess_metadata = "data/foodAccess.csv"
health_metadata = "data/health.csv"
insecurity_metadata = "data/insecurity.csv"
pricetax_metadata = "data/pricetax.csv"
ses_metadata = "data/ses.csv"
stores_metadata = "data/stores.csv"
assistance_metadata = "data/assistance.csv"
restaurant_metadata= "data/restaurants.csv"
county_geojson = "data/County.geojson"


# Read the data
foodAccess_metadata = pd.read_csv(foodAccess_metadata)
foodAccess_metadata
# Out:
#        FIPS State      County  LACCESS_POP10  LACCESS_POP15  \
# 0      1001    AL     Autauga   18428.439690   17496.693040
# 1      1003    AL     Baldwin   35210.814080   30561.264430
# 2      1005    AL     Barbour    5722.305602    6069.523628
# 3      1007    AL        Bibb    1044.867327     969.378841
# 4      1009    AL      Blount    1548.175559    3724.428242
# ...     ...   ...         ...            ...            ...
# 3138  56037    WY  Sweetwater   13391.715500   18934.737810
# 3139  56039    WY       Teton    6212.423697    6212.390430
# 3140  56041    WY       Uinta    4270.147119    4686.017653
# 3141  56043    WY    Washakie     931.411647     931.411647
# 3142  56045    WY      Weston    1240.493102    1237.267037
#
#       PCH_LACCESS_POP_10_15  PCT_LACCESS_POP10  PCT_LACCESS_POP15  \
# 0                 -5.056026          33.769657          32.062255
# 1                -13.204891          19.318473          16.767489
# ...

# %% [markdown]
# # Food access

# %%
il_foodAccess = foodAccess_metadata.loc[foodAccess_metadata["State"] == "IL"]
il_foodAccess
# Out:
#       FIPS State      County  LACCESS_POP10  LACCESS_POP15  \
# 595  17001    IL       Adams   10505.232660   10346.464750
# 596  17003    IL   Alexander    3858.855610    1748.049110
# 597  17005    IL        Bond    2080.987933    1281.433552
# 598  17007    IL       Boone    9063.970399   11409.517780
# 599  17009    IL       Brown    1910.444209    1662.659777
# ..     ...   ...         ...            ...            ...
# 692  17195    IL   Whiteside    9949.308567   13051.789530
# 693  17197    IL        Will  242455.252500  217703.442300
# 694  17199    IL  Williamson   11942.924020    9594.145863
# 695  17201    IL   Winnebago   72887.044310   76322.412930
# 696  17203    IL    Woodford    2900.696181    4535.317178
#
#      PCH_LACCESS_POP_10_15  PCT_LACCESS_POP10  PCT_LACCESS_POP15  \
# 595              -1.511322          15.655385          15.418781
# 596             -54.700323          46.842141          21.219339
# ...

# %%
il_access= il_foodAccess[["State","County","PCT_LACCESS_POP15","PCT_LACCESS_CHILD15","PCT_LACCESS_SENIORS15","PCT_LACCESS_POP10","PCT_LACCESS_CHILD10","PCT_LACCESS_SENIORS10"]]
il_access = il_access.rename(columns={"PCT_LACCESS_POP15": "lowaccess_pop_2015","PCT_LACCESS_CHILD15": "lowaccess_children_2015","PCT_LACCESS_SENIORS15": "lowaccess_seniors_2015","PCT_LACCESS_POP10": "lowaccess_pop_2010","PCT_LACCESS_CHILD10": "lowaccess_children_2010", "PCT_LACCESS_SENIORS10":"lowaccess_seniors_2010"})
il_access
# Out:
#     State      County  lowaccess_pop_2015  lowaccess_children_2015  \
# 595    IL       Adams           15.418781                 3.729229
# 596    IL   Alexander           21.219339                 4.556304
# 597    IL        Bond            7.212030                 1.655418
# 598    IL       Boone           21.064373                 6.245174
# 599    IL       Brown           23.967994                 0.433767
# ..    ...         ...                 ...                      ...
# 692    IL   Whiteside           22.311514                 4.872750
# 693    IL        Will           32.130504                 9.451649
# 694    IL  Williamson           14.458378                 3.456775
# 695    IL   Winnebago           25.848697                 6.238766
# 696    IL    Woodford           11.730078                 3.075731
#
#      lowaccess_seniors_2015  lowaccess_pop_2010  lowaccess_children_2010  \
# 595                2.741821           15.655385                 3.791903
# ...

# %% [markdown]
# # Health metadata

# %%
# Read the data
health_metadata = pd.read_csv(health_metadata)
health_metadata
# Out:
#        FIPS State      County  PCT_DIABETES_ADULTS08  PCT_DIABETES_ADULTS13  \
# 0      1001    AL     Autauga                   11.4                   13.0
# 1      1003    AL     Baldwin                    9.8                   10.4
# 2      1005    AL     Barbour                   13.6                   18.4
# 3      1007    AL        Bibb                   11.1                   14.8
# 4      1009    AL      Blount                   11.4                   14.1
# ...     ...   ...         ...                    ...                    ...
# 3138  56037    WY  Sweetwater                    6.8                    8.1
# 3139  56039    WY       Teton                    4.1                    4.8
# 3140  56041    WY       Uinta                    6.3                    9.0
# 3141  56043    WY    Washakie                   10.5                   12.0
# 3142  56045    WY      Weston                    7.1                   10.0
#
# ...

# %%
il_health = health_metadata.loc[health_metadata["State"] == "IL"]
il_health
# Out:
#       FIPS State      County  PCT_DIABETES_ADULTS08  PCT_DIABETES_ADULTS13  \
# 595  17001    IL       Adams                    9.0                   10.1
# 596  17003    IL   Alexander                   11.0                   11.4
# 597  17005    IL        Bond                    8.8                   10.0
# 598  17007    IL       Boone                    7.2                    9.4
# 599  17009    IL       Brown                    7.9                    8.2
# ..     ...   ...         ...                    ...                    ...
# 692  17195    IL   Whiteside                    8.9                   10.5
# 693  17197    IL        Will                    7.9                    8.5
# 694  17199    IL  Williamson                    8.7                   10.5
# 695  17201    IL   Winnebago                    9.2                   11.7
# 696  17203    IL    Woodford                    8.4                    9.6
#
# ...

# %%
il_health= il_health[["State","County","PCT_DIABETES_ADULTS08","PCT_DIABETES_ADULTS13","PCT_OBESE_ADULTS08","PCT_DIABETES_ADULTS13"]]
il_health = il_health.rename(columns={"PCT_DIABETES_ADULTS08":"Adult_diabetes_2008", "PCT_DIABETES_ADULTS13": "Adult_diabetes_2013","PCT_OBESE_ADULTS08": "Adult_obesity_2008", "PCT_OBESE_ADULTS13": "Adult_obesity_2013" })
il_health
# Out:
#     State      County  Adult_diabetes_2008  Adult_diabetes_2013  \
# 595    IL       Adams                  9.0                 10.1
# 596    IL   Alexander                 11.0                 11.4
# 597    IL        Bond                  8.8                 10.0
# 598    IL       Boone                  7.2                  9.4
# 599    IL       Brown                  7.9                  8.2
# ..    ...         ...                  ...                  ...
# 692    IL   Whiteside                  8.9                 10.5
# 693    IL        Will                  7.9                  8.5
# 694    IL  Williamson                  8.7                 10.5
# 695    IL   Winnebago                  9.2                 11.7
# 696    IL    Woodford                  8.4                  9.6
#
#      Adult_obesity_2008  Adult_diabetes_2013
# 595                26.5                 10.1
# 596                28.2                 11.4
# 597                27.9                 10.0
# ...

# %% [markdown]
# # Stores

# %%
stores_metadata = pd.read_csv(stores_metadata)
stores_metadata
# Out:
#        FIPS State      County  GROC09  GROC14  PCH_GROC_09_14  GROCPTH09  \
# 0      1001    AL     Autauga       6       4      -33.333333   0.110834
# 1      1003    AL     Baldwin      24      29       20.833333   0.133775
# 2      1005    AL     Barbour       5       5        0.000000   0.180786
# 3      1007    AL        Bibb       6       5      -16.666667   0.261540
# 4      1009    AL      Blount       6       6        0.000000   0.104637
# ...     ...   ...         ...     ...     ...             ...        ...
# 3138  56037    WY  Sweetwater       5       5        0.000000   0.113294
# 3139  56039    WY       Teton       6      11       83.333333   0.282592
# 3140  56041    WY       Uinta       3       2      -33.333333   0.142491
# 3141  56043    WY    Washakie       3       2      -33.333333   0.356168
# 3142  56045    WY      Weston       4       4        0.000000   0.550509
#
#       GROCPTH14  PCH_GROCPTH_09_14  SUPERC09  ...  PCH_SNAPS_12_16  \
# ...

# %%
il_stores = stores_metadata.loc[stores_metadata["State"] == "IL"]
il_stores
# Out:
#       FIPS State      County  GROC09  GROC14  PCH_GROC_09_14  GROCPTH09  \
# 595  17001    IL       Adams      11      10       -9.090909   0.164084
# 596  17003    IL   Alexander       2       2        0.000000   0.241109
# 597  17005    IL        Bond       3       1      -66.666667   0.169043
# 598  17007    IL       Boone       9       5      -44.444444   0.166193
# 599  17009    IL       Brown       2       2        0.000000   0.287233
# ..     ...   ...         ...     ...     ...             ...        ...
# 692  17195    IL   Whiteside       9       8      -11.111111   0.153408
# 693  17197    IL        Will      86     102       18.604651   0.127413
# 694  17199    IL  Williamson      16      14      -12.500000   0.241586
# 695  17201    IL   Winnebago      55      55        0.000000   0.186055
# 696  17203    IL    Woodford       9       6      -33.333333   0.232708
#
#      GROCPTH14  PCH_GROCPTH_09_14  SUPERC09  ...  PCH_SNAPS_12_16  SNAPSPTH12  \
# ...

# %%
il_stores = il_stores [["State","County","GROCPTH09","GROCPTH14","CONVSPTH09","CONVSPTH14","SNAPSPTH12","SNAPSPTH16"]]
il_stores = il_stores.rename(columns={"GROCPTH09": "Grocery_2009", "GROCPTH14": "Grocery_2014", "CONVSPTH09": "Conv_2009", "CONVSPTH14": "Conv_2014", "SNAPSPTH12": "SNAP_2012", "SNAPSPTH16": "SNAP_2016"})
il_stores
# Out:
#     State      County  Grocery_2009  Grocery_2014  Conv_2009  Conv_2014  \
# 595    IL       Adams      0.164084      0.149280   0.432584   0.447841
# 596    IL   Alexander      0.241109      0.266951   0.361664   0.533903
# 597    IL        Bond      0.169043      0.057907   0.563476   0.636980
# 598    IL       Boone      0.166193      0.092818   0.406249   0.389835
# 599    IL       Brown      0.287233      0.292740   0.574465   0.439110
# ..    ...         ...           ...           ...        ...        ...
# 692    IL   Whiteside      0.153408      0.140657   0.392043   0.457135
# 693    IL        Will      0.127413      0.148814   0.240011   0.256777
# 694    IL  Williamson      0.241586      0.208930   0.468073   0.402937
# 695    IL   Winnebago      0.186055      0.190613   0.378875   0.419350
# 696    IL    Woodford      0.232708      0.153112   0.310278   0.484855
#
#      SNAP_2012  SNAP_2016
# 595   0.739120   0.720959
# 596   0.774393   1.003396
# ...

# %% [markdown]
# # SES

# %%
ses_metadata = pd.read_csv(ses_metadata)
ses_metadata
# Out:
#        FIPS State      County  PCT_NHWHITE10  PCT_NHBLACK10  PCT_HISP10  \
# 0      1001    AL     Autauga      77.246156      17.582599    2.400542
# 1      1003    AL     Baldwin      83.504787       9.308425    4.384824
# 2      1005    AL     Barbour      46.753105      46.691190    5.051535
# 3      1007    AL        Bibb      75.020729      21.924504    1.771765
# 4      1009    AL      Blount      88.887338       1.263040    8.070200
# ...     ...   ...         ...            ...            ...         ...
# 3138  56037    WY  Sweetwater      80.883897       0.947359   15.269598
# 3139  56039    WY       Teton      82.206255       0.150277   14.985442
# 3140  56041    WY       Uinta      88.531111       0.227294    8.783976
# 3141  56043    WY    Washakie      83.886089       0.257823   13.617719
# 3142  56045    WY      Weston      93.812431       0.249723    2.996670
#
#       PCT_NHASIAN10  PCT_NHNA10  PCT_NHPI10  PCT_65OLDER10  PCT_18YOUNGER10  \
# ...

# %%
il_ses = ses_metadata.loc[ses_metadata["State"] == "IL"]
il_ses
# Out:
#       FIPS State      County  PCT_NHWHITE10  PCT_NHBLACK10  PCT_HISP10  \
# 595  17001    IL       Adams      93.012235       3.409684    1.156431
# 596  17003    IL   Alexander      60.487983      35.299830    1.881525
# 597  17005    IL        Bond      88.907024       5.971409    3.078568
# 598  17007    IL       Boone      75.246008       1.801902   20.247392
# 599  17009    IL       Brown      74.830618      18.379703    5.795012
# ..     ...   ...         ...            ...            ...         ...
# 692  17195    IL   Whiteside      85.922596       1.205169   11.034565
# 693  17197    IL        Will      67.237883      10.983382   15.617362
# 694  17199    IL  Williamson      91.503534       3.788598    1.960607
# 695  17201    IL   Winnebago      72.543402      11.974965   10.897631
# 696  17203    IL    Woodford      96.456652       0.481068    1.363025
#
#      PCT_NHASIAN10  PCT_NHNA10  PCT_NHPI10  PCT_65OLDER10  PCT_18YOUNGER10  \
# ...

# %%
il_ses = il_ses [["State","County","PCT_NHWHITE10","PCT_NHBLACK10","PCT_HISP10","PCT_NHASIAN10","PCT_NHNA10","PCT_NHPI10","PCT_65OLDER10","PCT_18YOUNGER10","POVRATE15","CHILDPOVRATE15"]]
il_ses = il_ses.rename(columns={"PCT_NHWHITE10": "White_2010", "PCT_NHBLACK10": "Black_2010", "PCT_HISP10": "Hispanic_2010", "PCT_NHASIAN10": "Asian_2010", "PCT_NHNA10": "AmericanIndian_2010", "PCT_NHPI10": "PacificIslander_2010","PCT_65OLDER10":"65older_2010","PCT_18YOUNGER10":"18younger_2010","POVRATE15": "poverty_2015","CHILDPOVRATE15": "childpov_2015"})
il_ses
# Out:
#     State      County  White_2010  Black_2010  Hispanic_2010  Asian_2010  \
# 595    IL       Adams   93.012235    3.409684       1.156431    0.640806
# 596    IL   Alexander   60.487983   35.299830       1.881525    0.194222
# 597    IL        Bond   88.907024    5.971409       3.078568    0.377082
# 598    IL       Boone   75.246008    1.801902      20.247392    1.231423
# 599    IL       Brown   74.830618   18.379703       5.795012    0.230647
# ..    ...         ...         ...         ...            ...         ...
# 692    IL   Whiteside   85.922596    1.205169      11.034565    0.459845
# 693    IL        Will   67.237883   10.983382      15.617362    4.495248
# 694    IL  Williamson   91.503534    3.788598       1.960607    0.839399
# 695    IL   Winnebago   72.543402   11.974965      10.897631    2.276591
# 696    IL    Woodford   96.456652    0.481068       1.363025    0.537968
#
#      AmericanIndian_2010  PacificIslander_2010  65older_2010  18younger_2010  \
# ...

# %% [markdown]
# # restaurant

# %%
restaurant_metadata  = pd.read_csv(restaurant_metadata)
restaurant_metadata
# Out:
#        FIPS State      County  FFR09  FFR14  PCH_FFR_09_14  FFRPTH09  \
# 0      1001    AL     Autauga     30     36      20.000000  0.554170
# 1      1003    AL     Baldwin    112    132      17.857143  0.624282
# 2      1005    AL     Barbour     21     22       4.761905  0.759301
# 3      1007    AL        Bibb      7      5     -28.571429  0.305131
# 4      1009    AL      Blount     24     21     -12.500000  0.418549
# ...     ...   ...         ...    ...    ...            ...       ...
# 3138  56037    WY  Sweetwater     27     33      22.222222  0.611787
# 3139  56039    WY       Teton     25     23      -8.000000  1.177468
# 3140  56041    WY       Uinta     15     16       6.666667  0.712454
# 3141  56043    WY    Washakie      8      6     -25.000000  0.949780
# 3142  56045    WY      Weston      4      3     -25.000000  0.550509
#
#       FFRPTH14  PCH_FFRPTH_09_14  FSR09  FSR14  PCH_FSR_09_14  FSRPTH09  \
# ...

# %%
il_restaurant = restaurant_metadata.loc[restaurant_metadata["State"] == "IL"]
il_restaurant
# Out:
#       FIPS State      County  FFR09  FFR14  PCH_FFR_09_14  FFRPTH09  FFRPTH14  \
# 595  17001    IL       Adams     29     32      10.344828  0.432584  0.477697
# 596  17003    IL   Alexander      1      0    -100.000000  0.120555  0.000000
# 597  17005    IL        Bond      6      7      16.666667  0.338085  0.405351
# 598  17007    IL       Boone     26     26       0.000000  0.480112  0.482652
# 599  17009    IL       Brown      2      3      50.000000  0.287233  0.439110
# ..     ...   ...         ...    ...    ...            ...       ...       ...
# 692  17195    IL   Whiteside     30     30       0.000000  0.511361  0.527463
# 693  17197    IL        Will    438    477       8.904110  0.648918  0.695925
# 694  17199    IL  Williamson     41     42       2.439024  0.619064  0.626791
# 695  17201    IL   Winnebago    202    202       0.000000  0.683328  0.700071
# 696  17203    IL    Woodford     14     19      35.714286  0.361991  0.484855
#
# ...

# %%
il_restaurant= il_restaurant [["State","County","FFRPTH09","FFRPTH14", "FSRPTH09","FSRPTH14"]]
il_restaurant = il_restaurant.rename(columns={"FFRPTH09": "FastFood_2009", "FFRPTH14": "FastFood_2014", "FSRPTH09": "FullServiceRestaurant_2009", "FSRPTH14": "FullServiceRestaurant_2014"})
il_restaurant
# Out:
#     State      County  FastFood_2009  FastFood_2014  \
# 595    IL       Adams       0.432584       0.477697
# 596    IL   Alexander       0.120555       0.000000
# 597    IL        Bond       0.338085       0.405351
# 598    IL       Boone       0.480112       0.482652
# 599    IL       Brown       0.287233       0.439110
# ..    ...         ...            ...            ...
# 692    IL   Whiteside       0.511361       0.527463
# 693    IL        Will       0.648918       0.695925
# 694    IL  Williamson       0.619064       0.626791
# 695    IL   Winnebago       0.683328       0.700071
# 696    IL    Woodford       0.361991       0.484855
#
#      FullServiceRestaurant_2009  FullServiceRestaurant_2014
# 595                    0.686168                    0.850899
# 596                    0.482218                    0.533903
# 597                    0.845213                    0.752794
# 598                    0.313920                    0.334144
# ...

# %% [markdown]
# # Merging data

# %%
il_merged = il_access.merge(il_health,left_on="County", right_on="County", how="left")
il_merged
# Out:
#     State_x      County  lowaccess_pop_2015  lowaccess_children_2015  \
# 0        IL       Adams           15.418781                 3.729229
# 1        IL   Alexander           21.219339                 4.556304
# 2        IL        Bond            7.212030                 1.655418
# 3        IL       Boone           21.064373                 6.245174
# 4        IL       Brown           23.967994                 0.433767
# ..      ...         ...                 ...                      ...
# 97       IL   Whiteside           22.311514                 4.872750
# 98       IL        Will           32.130504                 9.451649
# 99       IL  Williamson           14.458378                 3.456775
# 100      IL   Winnebago           25.848697                 6.238766
# 101      IL    Woodford           11.730078                 3.075731
#
#      lowaccess_seniors_2015  lowaccess_pop_2010  lowaccess_children_2010  \
# ...

# %%
il_merged = il_merged.merge(il_stores,left_on="County", right_on="County", how="left")
il_merged
# Out:
#     State_x      County  lowaccess_pop_2015  lowaccess_children_2015  \
# 0        IL       Adams           15.418781                 3.729229
# 1        IL   Alexander           21.219339                 4.556304
# 2        IL        Bond            7.212030                 1.655418
# 3        IL       Boone           21.064373                 6.245174
# 4        IL       Brown           23.967994                 0.433767
# ..      ...         ...                 ...                      ...
# 97       IL   Whiteside           22.311514                 4.872750
# 98       IL        Will           32.130504                 9.451649
# 99       IL  Williamson           14.458378                 3.456775
# 100      IL   Winnebago           25.848697                 6.238766
# 101      IL    Woodford           11.730078                 3.075731
#
#      lowaccess_seniors_2015  lowaccess_pop_2010  lowaccess_children_2010  \
# ...

# %%
il_merged = il_merged.merge(il_ses,left_on="County", right_on="County", how="left")
il_merged
# Out:
#     State_x      County  lowaccess_pop_2015  lowaccess_children_2015  \
# 0        IL       Adams           15.418781                 3.729229
# 1        IL   Alexander           21.219339                 4.556304
# 2        IL        Bond            7.212030                 1.655418
# 3        IL       Boone           21.064373                 6.245174
# 4        IL       Brown           23.967994                 0.433767
# ..      ...         ...                 ...                      ...
# 97       IL   Whiteside           22.311514                 4.872750
# 98       IL        Will           32.130504                 9.451649
# 99       IL  Williamson           14.458378                 3.456775
# 100      IL   Winnebago           25.848697                 6.238766
# 101      IL    Woodford           11.730078                 3.075731
#
#      lowaccess_seniors_2015  lowaccess_pop_2010  lowaccess_children_2010  \
# ...

# %%
il_merged = il_merged.merge(il_restaurant,left_on="County", right_on="County", how="left")
il_merged
# Out:
#     State_x      County  lowaccess_pop_2015  lowaccess_children_2015  \
# 0        IL       Adams           15.418781                 3.729229
# 1        IL   Alexander           21.219339                 4.556304
# 2        IL        Bond            7.212030                 1.655418
# 3        IL       Boone           21.064373                 6.245174
# 4        IL       Brown           23.967994                 0.433767
# ..      ...         ...                 ...                      ...
# 97       IL   Whiteside           22.311514                 4.872750
# 98       IL        Will           32.130504                 9.451649
# 99       IL  Williamson           14.458378                 3.456775
# 100      IL   Winnebago           25.848697                 6.238766
# 101      IL    Woodford           11.730078                 3.075731
#
#      lowaccess_seniors_2015  lowaccess_pop_2010  lowaccess_children_2010  \
# ...

# %%
il_merged.columns
# Out:
# Index(['State_x', 'County', 'lowaccess_pop_2015', 'lowaccess_children_2015',
#        'lowaccess_seniors_2015', 'lowaccess_pop_2010',
#        'lowaccess_children_2010', 'lowaccess_seniors_2010', 'State_y',
#        'Adult_diabetes_2008', 'Adult_diabetes_2013', 'Adult_obesity_2008',
#        'Adult_diabetes_2013', 'State_x', 'Grocery_2009', 'Grocery_2014',
#        'Conv_2009', 'Conv_2014', 'SNAP_2012', 'SNAP_2016', 'State_y',
#        'White_2010', 'Black_2010', 'Hispanic_2010', 'Asian_2010',
#        'AmericanIndian_2010', 'PacificIslander_2010', '65older_2010',
#        '18younger_2010', 'poverty_2015', 'childpov_2015', 'State',
#        'FastFood_2009', 'FastFood_2014', 'FullServiceRestaurant_2009',
#        'FullServiceRestaurant_2014'],
#       dtype='object')

# %%
il_final = il_merged.drop(columns=["State_x","State"])
il_final.columns
# Out:
# Index(['County', 'lowaccess_pop_2015', 'lowaccess_children_2015',
#        'lowaccess_seniors_2015', 'lowaccess_pop_2010',
#        'lowaccess_children_2010', 'lowaccess_seniors_2010', 'State_y',
#        'Adult_diabetes_2008', 'Adult_diabetes_2013', 'Adult_obesity_2008',
#        'Adult_diabetes_2013', 'Grocery_2009', 'Grocery_2014', 'Conv_2009',
#        'Conv_2014', 'SNAP_2012', 'SNAP_2016', 'State_y', 'White_2010',
#        'Black_2010', 'Hispanic_2010', 'Asian_2010', 'AmericanIndian_2010',
#        'PacificIslander_2010', '65older_2010', '18younger_2010',
#        'poverty_2015', 'childpov_2015', 'FastFood_2009', 'FastFood_2014',
#        'FullServiceRestaurant_2009', 'FullServiceRestaurant_2014'],
#       dtype='object')

# %%
il_final.to_csv("il_final.csv")
